# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <B>Amjad Salameh</B>

# %% [markdown]
# senior java developer

# %% [markdown]
# <I>I am interested in data science because I love AI amd ML</I>

# %% [markdown]
# <H3> my code add 2 number</H3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# <hr>

# %% [markdown]
# <ul>
# <li>i1</li>
# <li>i2</li>
# <li>i3</li>
# <li>i4</li>
# </ul>
# <hr/>
# <ol>
# <li>i1</li>
# <li>i2</li>
# <li>i3</li>
# <li>i4</li>
# </ol>
# <table border=1>
# <tr><td>c1</td><td>c2</td></tr>
# <tr><td>c3</td><td>c3</td></tr>
# </table>
